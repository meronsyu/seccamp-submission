# %% [markdown]
# <a href="https://colab.research.google.com/github/meronsyu/seccamp-submission/blob/main/multiEpochs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Out:
# --2024-05-17 15:25:17--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt’
#
# input.txt           100%[===================>]   1.06M  --.-KB/s    in 0.06s
#
# 2024-05-17 15:25:17 (18.7 MB/s) - ‘input.txt’ saved [1115394/1115394]

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16
block_size = 32
max_iters = 5000
num_epoches = 10
eval_interval = 400
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()


chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }

encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
for epoch in range(num_epoches):
  for iter in range(max_iters):

      # every once in a while evaluate the loss on train and val sets
      if iter % eval_interval == 0 or iter == max_iters - 1:
          losses = estimate_loss()

      # sample a batch of data
      xb, yb = get_batch('train')

      # evaluate the loss
      logits, loss = model(xb, yb)
      optimizer.zero_grad(set_to_none=True)
      loss.backward()
      optimizer.step()

  # generate from the model
  context = torch.zeros((1, 1), dtype=torch.long, device=device)
  print(f"train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")
  print(f"Epoch {epoch + 1} generated text:")
  print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# train loss 1.6758, val loss 1.8353
# Epoch 1 generated text:
#
#
# NORTHUREN:
# O, will to love this: well way, we arthrians meage and bartht he usquit toth heath!
# Hate away, my feanst, wizowous
# Yout proof it heart milend liblees if ease heig;
# Stirm in ov the dead flong hightrable, like dipeaver-hear on himy:
# Suppiness hiw you love.
# I crow, this death:
# I let like again Windon him evicker's they still ceem in his soun
# And strume king threford so;
# And his love, I male gatiffife
# With my of thange be! stiddow, wards be his grest hunce must are noble-his chan you!
# My firear oke mary life come, my me
# broked his menn; for we men.
# Was might but he win the cond, with comfor:
# I shout might. And as death is theree evereed me overead?
# Canscity our flooe?
# Yourse: in dous be feRI tall: there loves
# Then full side he neemover any this abber again
# Abun with soul. Dorself From the welconest in herces hows,
# And I it him. Come in now this reeven dook, if out orn fen eyemble liport,
# This be thang thereing Eisles be thou so han will be mawatch time wout
# Shaft us you gones ear road, it we soars, I lew night humble the vorthis did fland,
# And that how him!
#
# See, messent now sight wording.
#
# GREMIOLUS:
# Whithe word, was a down want: his eaIn
# Before anience poly in toan Pitone.
#
# GLORIAS:
# Whichen Reing biwm not my have eath I dismot, detibly's let weep mother brook!
# Are coldre end just deed of throughs?
#
# Secome Norbing it is caper's lover done him, love come.
# Then vanward vonbust than this neear ell him;
# And him your toomat's froe you thelege,
# Such in of Ricarrow of his heaves; find.
#
# HARTIO:
# My crame, ever; for but of a-hathere
# Count.
#
# PROMPONCE:
# My, lord rist life evencly preing himself, but
# for this like! Whence a rishe. are lighard a give affidely,
# Fhirst morastion; such, pars by well.
#
# LISADY:
# A wifly this father, my rocle cittato thou liceonly talle upon the with fair? Boling true,
# As you heread 'lift he pusict of hight wich would think;
# The with ry promind me, and, and my and towern'd love,
# Where pating tours on down'd fight his such come.
#
# MARTIIIA:
# Marr
# train loss 1.5689, val loss 1.7428
# Epoch 2 generated text:
#
# Be everence, that him lost as beting in time the duke and frass the dead is twater.
#
# First Itwnry Lewit borokieve I'll to care love
# To thee the funershred would siding it is dead near in that you.
# That I shall be nothing love that ne'er,
# To next, sure Porsomice! and honour, with thou thy assistical adving.
#
# VALT:
# Thou may touch.
#
# CAPULET:
# The dismise, know, you  my past, go see here on.
#
# DUKE VINCENTIO:
# Lay you, my sear moves spoke this wood,
# Is dead, God, here know so pride sin him; forget seeking my plouds,
# And have to a sid, thou bight out brieght;
# And and husband exproc, and well wind set!
#
# DUKE VINCENTIO:
# Thou herefull as be or more.
#
# Fertyst:
# And slept for you padty me worse thee is first, need;
# But I'll itwouch for the crown kingdoms;
# And if me thou bitting Horn, Lord but had with watter woe and alog;
# Unless you! and hours, till burn it. I know: to me, me you.
#
# Sony Worthon:
# Thus like to dread to brumble grace crives you'll'd
# His by tonging, that jodge, him, to I wife,
# More is throw will been hisford,
# Baging my lord--'
#
# CAPULINGBRO:
# What, so boy, in all, my loss, that I come: you, I priar.
#
# FirsBY:
# Ingo? stren not you spared there.
# Aio, and alrow'd yours: her I womal'st besting a prides?
# My lords, whom wen you; 'tis give your cause a hurr pain of my ssumn
# To friend it the hurt; bust will chomment.
#
# NORTHUMBERLAND:
# Hear that tenrous?
# There Warwick'st me remain and agaty,
# And to may door vair enebrut, and
# Oar o' apple wods go oads gatex-fition.
#
# AUTOLYCUS:
#
# AUFIDIUS:
# Whyly nothing realoing to me, ore is banishments
# And vinges, and what king, hear! say shamp the formot boward
# On lay brother throw world it best to him. This way kneep and lible a jury armition'd she
# She hads not
# My heath of marry joy soun the deads of old-morrow her scare tendeed, Histes, God,
# Will hast, thiquotions son freal nob!
# Here head, you maye worrow.
#
# Prown:
# Make on Gione a thon's fool: his edeeth your hands;
# And God a sock: world noble upon and me wrong;
# And, and much a mulkning indeed of
# train loss 1.5197, val loss 1.6976
# Epoch 3 generated text:
#
# GLOUSpaocithed:
# I go she not you was't your cours like, killingly bysents,
# Since image'd yiel soos, noble haste,
# Where all screts the sound is the gone then was he yet?
#
# PETRUCHIO:
# To the Bolingbroke, comband, I my soul, is let's noble
# Of thee lightine ouch clawagemon'd,
# Promphein and smile very halt ask your honours it.'
# Or be as is life geing him humbly libe him in night
# Cast a rated puten thee, from the should I
# sour love, with menise to but at supage up.
#
# ISABELLA:
# Come, sir, away hands was would know.
# Well,regace yet thrown, now:
# Your foul made be earl noble come our inty yoursempate,
# Breaks on so sweet so sacretely sight,
# thing kings mastis you? ever a watcholes
# thronous fondrable to what though is him no should of
# rough'dingly your slady.
#
# EDWARD:
# Wound, I plant-diray, your auches! villate moke me! all whereoI to no cour'd
# To fear force the oard; andamy mercy,
# Your norford city the untall prays,
# Clifford's cide, to her of trici.
# Myself Hasting time his'd the villa,
# And but myself from eye not awrinken to me in that kingdom again?
#
# GREGORY:
# Your health-ratieon how came hold your wick is that her blace;
# To you cousin, for my deadle shall be knocket:
# More me, good to so be men.
# Poide after, and friends and termity
# Them his course hell give you have shall us.
#
# PORIA:
# First to-morrow?
#
# YORK:
# My love:
# Or greign one to the morrow, we most your heart danch a woful nothing I shall easy have it be a bost gone;
# God my crack in plain father--dalination;
# And it one the Parisonous his fatherous:--
# Marry quietake me in Mayour shall be the lord.
#
# Togles Within your of Catile:
# Let's musicious, my lip datch, now forn,
# than mayond flalls fooliner, shade and rain,
# In collent your herish that not man,
# This intell then leword, That your both dick, Herturage gardenler.
# Be yours, your potenie.
# Where, let Gennow, I would come, I were care like your -gives him;
# Adiuse that heaven she'll danhan be our wisd.
#
# KING RICHARD II:
# Heave thoughn saw this:
# a sens I pay and signable men draptin
# train loss 1.4982, val loss 1.6905
# Epoch 4 generated text:
#
# A cogike and
# To pale the tumners of Volsces, Buckinghal,
# And laterdon it of souls to save
# My subject other unthank that him that news
# A swaying to is rochise, and it too often it?
#
# JULIET:
# Or sur
# Chall it's buriend aff;
# For you think shall serchiriers:
# A bratten fout, sir, whence that you are Jack to o'ctor,
# 'Would 'twices but not, and to him.
#
# KING MARRAYCUS:
#
# WARWICK:
# Ay, labus, given me butch, that ever to,
# Therefore that more is your upriest,
# On make the that all mind
# porspets: thou? go wake my queen,
# For he is valus, indeed all Lord!
#
# CORIOLANUM:
# The house roolling friend that,
# That sorrow provody on shame fulcted, wrong to,
# Thy way, what but arms make upon as will young souls,
# And that have learn the
# inguess moneyhration's how excertacon,
# Unclishaluing darders.
#
# Thirds Gentle mush'd, his dobt, you were most direst?
#
# YORK:
# What's lacterne ower-vie, thes I see,
# That chance me to becomes it up; for siciliss to your tongues;
# She buriess criests on, to how favil,
# And though a pluch telth hours and here friar lands of yield sisteral me them; back, he hear reno:
# Uncempt with not with Larty, that Yord, peritions,
# Well, what is it commat. I had raise, endery will he will it
# forth mend make to then, wherere my pater:
# Or therefore, strawn to be to
# Thou spott and the viold; and in doubly of EUMBERLAND:
# Sweet say you have tay, foll, Richard,
# On thear then do comes you.
#
# HOMENRY BOLENCK:
# Oher, why! I'll saken, 'abuld
# vition and tho
# prage with renous me but me
# Butter, a bad sent
# To readyer'd be tale overe.
#
# First Lewis, Chrick, banist the earth, shall
# And for they cheech shrow, and you know ere and
#
# BAMNOT:
# Why, should he be wreak your King Come touch.
# I'll not alaid not beg me, my loding, there
# madve sheres you whateful tire, that thou shalt be thou not, on to think
# Them on a fight.
#
# LUCIO:
# The away, how partined my purpose
# The proud stood from this vocure
# Whom, from birth his bute of morney
# strea; in with when my earp, in vanicy, the reconour mosts,
# To thy what, sir? it wa
# train loss 1.4744, val loss 1.6719
# Epoch 5 generated text:
#
# KIZ shore happrocased was deward too
# foot-shows good frame, my leave coysless wears
# There-noad, my coftation fairst on.
#
# Second Convent:
# A men, bethold's passaken captain. I'll reck:
# Thou do, hadst, see him, come as his
# worlds.
#  it is the guilts, and their goodress,
# Till best thou must be yourselves.
#
# ROESBISHOP OF MERCUMIO:
# How doth I sore you. Course, both you know thousand and nobles
# This elemb, hod liborts one on more.
# For my heaven, if God, to helpatory.
# Make it leful much, how hold myself?
#
# AUFIDIUS:
# Go, I will not titain, so. And well touchmen again,
# It take, worse possess you have I do theam?
#
# HORTENSIO:
# How death there due
# Are is sooth to short unclalling long-ontrity leave-passcer you honour's very tongue.
#
# SICINIUS:
# Not a ole 'tis in thy king's virtue overcy,' in my first,
# Coriolanus, son thy butches from you mean shot:
# I was a nore! O, now I'll not woe,
# Tither is I swear with leave, you shalt your gently shadoke the king:
# King Tybers moves thy sweet fields my hollo.
#
# KING RICHARD II:
# TaKe renow, From thou canse answer,
# Will bust sound, thus our man, but you comestoman.
#
# TYBALT:
# Take o't, my oardy and broth,
# Wartitiim booly tonatural their worsers? O sless in the charge,
# This in thrown are dog'd whospat I pray may knutions!
# Not more happy him? do not Reareth his side an equires king,
# By the place, and tear. I am my look!
#
# QUEEN ELIZABETHASTIO:
#
# WICKINk, gordshing, and Tower, letter with you;
# Lead her, and, alas our told to plorous peap not this?
#
# Should JUMNIA:
# What is his waant answer withorst thus?
#
# LEONTES:
# Ut, speak, and I will save his heavy? for in Your tubling fair and feast.
#
# KING EDWARD IV:
# Paught thing peace, mayone worser'd!
# Ay, and I'll good and Cespect: I was?
#
# First Servant:
# What I loud, I do not but so,
# Is ahy holdion and upon't our theats;
# My wife
# In punty friars I must not them.
#
# GLOUCESTER:
# Naythangitdos equ
# Do wept us and ple's tale giansted the mate.
# Youble, sure in the seaso.
#
# KING,
# Your raffling at Gery goodly affriana,
# A funting of
# train loss 1.4527, val loss 1.6659
# Epoch 6 generated text:
#
# To bale as advise woe:
# So Gord's I, desperata. Tatch? If he comes to Fireth in sacred gone doubt?
#
# DUKE OF AUMERLE:
# Trights to Tybastiples of march;
# For they is the gods undertal of your promise.
#
# TLUS:
# There, sire too bed. Now, go his heart southorrify he,
# If they had need till then at predfate by cause of digers,
# Ere not. Peerform's keep.
#
# BRUTUS:
# Hath got to kin me absolute,
# No, suffied reasons him and such usetiated by that all an ends.
#
# pows?
#
# VIRGILIA:
# Well, tell, profess'd and perventive him.
#
# First George:
# I best it marror: receive that doth it by the death;
# So lost, for I well safe, I would reighbour brains, I pery knees as sweet-way,
# As queens! If thy coarly's Jufovered execute's before!
#
# HALTINGBURY:
# No! say Angelo be an is. I proceed.
#
# NORTHUMWARD:
# I that well not tears it weed; they with oute.
#
# First Citizen:
# No, now that as he
# are in a?
# A good masterbrad: yet.
#
# First Citizen:
# you cry, we hatle.
#
# LUCIO:
# Pray you infierced no air: both Cobutr's well,
# By great and knows the I is sended upon Edward of fortune,
# Forgivers throath?
#
# First Servant:
# I rest had fiff? there's my eito of this deny,
# Hereafter with twice of my sone that's us, as thy frot but in precton two our churcy,
# To rescians,--
#
# Leeivate tearth:
# Wlet you fear'st any heeart in fare night.
# There is the world-pauties
# Oftempt be for deeds we begin, you that bette!
# The Duke is his rest of the kept
# Yet dangerous colly place
# Could not time can shift of will,
# This art those learn the nothing craitors they prove-whither's proof.
#
# CORIOLANUS:
# With all a plue at feed!
#
# NORTALUS:
# If it is strong rounse himself
# To anner-toget? O migool? Thrive. Then wear-intell is bistp to
# Course guestless scanded.
#
# WARWICK:
# O, put what thoughts,
# Or and hore ancheses compane.
#
# Servant:
# How that it is be accezins; and ready: let me I was eleck;
# How threse deswerb; but that I his title;
# Madam you by thiteste, to fits
# their effect commisful, deep might me;
# I lose, sir, what tears you thou;
# If thin are thou, sir, wife that go c
# train loss 1.4521, val loss 1.6452
# Epoch 7 generated text:
#
#
# KING HENRY VI
#
# MENENIUS:
# Bidesing to go, snew his in their dismemns with the lad two racled discates
# from sounds in the curea,
# And stand not now friend. What
# By dead? I do satter'd for- whom highness and
# mine ince with fore Gold, to lip and answer'd never strangely; make for fine on
# the matter's if what olling to the toward at is help
# An hell the approacher
# More coward in thy fraught as so been junty of howly throw
# Tybalk but be so o'
# For it, sincess nurse to thy father to such fless!
# She kingly save; for Dickland, good lords.
#
# LADY GREY:
# Wold, enter, my lady that I promised to suspy bring snuck to thee to Nake
# Talumion,
# And little bail but stand them folk
# I found trike him to't to thu' oatF Angelo He,
# Chereion thy darkind and if accuse goss
# Once kinglish'd, and done stalles
# To termish for the did wears talet me:
# You come gues, inclingly times into answer?
# Under melance; thou's entrange Lord of Northumberant writy together
# Of stoth at my slaught is about
# The fathers of Glad, which you to save lies
# She do answer, but strive to another present and,
# Go and noise to Gentlemain, and none eye to Letchase me you have a brain,
# Siles anvever God's precares what
# The lest way he see you posslant.
# Strief I, is does, and welcome is denied that I cannot-such
# Do your guess
# Thousand thungst it. Is brack on my disdared loves citizens,
# Come, this comfort slew them fare ost,
# And the for threetoly horse, son, much for innot,
# Say not myself so. The hanged wancle;
# Have die, discordy on this, grief hadst to be ancient
# With an son and steem'd with him for my lesser for sweet neck,
# More than we have hath seek, else an ide calm
# His wase, or steal on executioner'd.
#
# JULIET:
# Citizens; but means we his sullent.
# Marquis-it spokes least we
# stlewell enrient; and his companion'd stay ome the charit of if
# from her night me; to thing the sine
# 'Twas you shall newful holy he will furict too legre's defend, sun the
# see-besiery:
# But, gived, go ontented. 'Tis mine heart, whose more will say are
# For I sta
# train loss 1.4427, val loss 1.6406
# Epoch 8 generated text:
#
# He carror! would he lady uncle.
#
# Jeepherd:
# I'll laduy seaping it, to love a cerent forward Georgehoes doubt,
# That corbing MercEY:
# These purged is here. His profit
# dark of thy fatal disgrace alcomes sprove but at thy prettil.
#
# RUTYBERS:
# Your milcus hold.
#
# LEONTES:
# Is in he way thing anothil.
#
# First Sequest Warwick:
# Now I'll be sading conscience of our sleeping nife and yiece,
# When me deseners, I'll knot a Marcijest,
# My flindly single was buck'd in his wreck!
#
# ANGELO:
# My lord.
#
# DUKE VINCENTIO:
# But I was lift to any received, my right,
# To lother.
#
# Second Murderer:
# But it shall I find he were may more tock at what?
# Thus we keep that this highbound,
# We much asarticular, tell heard up thou shalt be justice;
# And came, and we art keep your precilous stady?
# And they grant learn.
# Keeper you not so face, wruck up thy widow.
#
# DUKE VINCENTIO:
# Madam windre such a king badle:
# as and cannot art thee.
#
# JULIET:
# They espect
# And then his name of lightness me.
#
# ANGELO:
# I set's get in dust,
# And thereof many noble Duke of York?
#
# ANGELO:
# This are that is my't.
#
# LADY ANNE:
# Thou knit this mother, more hand friend
# Get me his prince day, and not of our man
# England action sseal to myrlime.
# Them but, what Venush, wereigh.
#
# DERBY:
# My good ceanly claving knave.
#
# ROMEO:
# Into his thieldwere man? This word is mine
# Ere all I. They are minds art slow: too our god's storn in my father, stay you much lends make
# Is freel ever last, my else offer dig all
# This mishes what I am art grace? The dark ide the harnest are thering for no brother.
#
# SAMPSON:
# One done discudal.
#
# CORIOLANUS:
# And that haste,
# In fetch,
# Turn to Come away ye, we liBknoced to-naugh, hereign image:
# How wefore queen and your grity, and me not did long his false
# Stay so smoles, and discouth a tears?
#
# TRANIO:
# I think take us a will think yet this:
# And, BeneWere you, it a cannot sweet down natond.
#
# ISABELLANDISBUDINGARET:
# Heready thou, a menting in, his pirection,
# Gautions of our way,' and. How thus,
# But lords, as mounty's purch.
#
# Polaping Ange
# train loss 1.4303, val loss 1.6326
# Epoch 9 generated text:
#
# Greecial in that years that you tower her Hastings.
#
# EDWARDION:
# But is thus he.
#
# BASTINGS:
#
# First Citizen:
# Winds? What then sathouts, and the strong
# and thought part our middly, nothing come a spirit alating my foot.
#
# CLARENCE:
# Be that face thou wert know; a should it have struites,
# With quuckles seem, even
# man your hand. O thou
# Thieve thee atood for which they to the heavy heart word my marker, and would I on,
# His world in cholers.
#
# POLIXENES:
# Knocks;
# And if the name weed then show their
# son, that we make to thim; there, is within maid out good service 'Corn,
# Where's the seve as
# I'll be to what no measure? O the troughs and he impurpies
# Capt that would trodded again! your spresh hangs; I am widow
# executions, and the gates in 'long a nature great my pitiful
# Were how the part, who
# progent longer littly clire, with so found away:
# A worthy very not to will? With the cordial in thee,
# fords her it be wonder sond! I catclude
# And beat in our
# bey? Jucher: noy
# to measures
# That save you to't.
#
# QUEEN ELIZABETH:
# Whilles bend from me well the deep of thread;
# And you access respect it on on Sicial to night.
#
# BARTINA:
# Then, thou beart a
# shoold say there's shall not thus
# to light thou see Isabel.
# Fort I wock, for I kill and you.
#
# QUEEN:
# Dost:
# I were eachers it o'er-i falight!
# Uncient by none, which for have I
# Have I come my rancher, to my heart: part given,
# Than Peolation on, they will not take him to hear thee protections come
# I was hath suffedimed
# but their painted that you at his repenignable.
#
# GREY:
# With thy baptierying hath butcher'd
# Six parished at thy gradiet, and look talk's head;
# And so favour fant of chite, then?
#
# SICINIUS:
# How shows out some setegrel, by thou shalt fex,
# Or a cleased must sort I. Get me, sit is multer, as I deford.
#
# DOTHASS:
# Must aport it again,
# That we will you to some hair to night:
# To chase you camed longe, senate fees of thy look loves.
#
# COMINIO:
# Come, if I so, these horn to his good,
# From flatter you!
# And not this no told her, as I will another
# To al
# train loss 1.4278, val loss 1.6377
# Epoch 10 generated text:
#
#
# PAULINA:
# Not Force wrong'd of young, aman:
# Which, the renothen warst Hasty thou love!
# Then no give the through for how
# In uncle all found me! You blest advotire proceedy.
# Queen the every of down so and beams in virgal deed.
# Thy must we find me to act, yet did not the point often her:
# And! Romeo and knownced feel to be fellow from thy dull hast ere, I tell in your cardicing witness
# My sir, and ethought that cluditions.
# What's
# What have linds to set
# Her doubted else interms: hence! 'tis know fortune?
#
# Profanethon:
# match, I heard the captive Clarence:
# O, let thou thinks he fortune to me most born,
# And; let's permey that, want on means
# Mother's like thee, whatise your hands when been come heaven,
# I children forth and no
# be it. Pluch at in thyself pent my louring fear of razely the dishonour,
# To proud me yours to mercy: let himself me.
# What's mother; why every and thy present
# Cursed with tiell plaint of her,
# Even my fight in tell my tree wonderwart,
# It bid prospired thee; he is none on the lament.
#
# GLOUCESTERSS:
# Grace may he, I'll man I hope on of this truction saw
# 'tis birth with gates to rying,'tis so,
# In sabding, reclined, it is not
# To woman here, if your young
# judged, then heart like.
# The foul seems contagemy; meeding senting to our Buckingham,.
#
# WARWICK:
# Let me would thy sorrow and her report in Lost thou have lickles,
# And tear you wakers my life to our warshing
# Were what is my very misery thrivers it sail think
# That mightrey's deedly and an ear
# Sholling ones will die in the Duke offence
# For Cae uponerpretial to us a cury,
# soeting vault's by metimes!
# To mourt, my lord.
#
# Send Murder:
# No nofficers he true!
#
# KING RICHARD III:
# Why have have a fortunt to then striegn,
# Whim to the Lady Lord Hastings and rotten abrived:
# Why, in richetity to our him. Away a well:
# Marry't effly tarchetion by. Live close,
# Which not to seem his spake.
# Julietion; but will you mistrone,
# I must thou goost not sondified prove
# You take on thee that early colourageous but
# As your fatherling and ibj
